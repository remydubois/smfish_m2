# %%
from FishAnalyser import *
im_path = '/Users/remydubois/Desktop/Remy/_REMY/Opera_Conf/3D/B09_DYNC1H1/r02c09f05-ch1sk1fk1fl1.tif'
im = FQimage()
im.load(im_path, shape=None)

# %%
im.detect_and_fit()
# Out:
# Detecting...
# 801 spots detected.
# Fitting...
# fit.

# %%
im.show_spots()
# Out:
# /Users/remydubois/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
