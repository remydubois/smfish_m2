# %%
from FishAnalyser import *
dapi_path = '/Users/remydubois/Desktop/Remy/_REMY/hilo_tournant/Stacks/E09_MELK/171208_835_w3TIRF-405.TIF'
dapi = DAPIimage()
dapi.load(dapi_path)
# Out:
# /Users/remydubois/Documents/rd_repos/CBIO/spot_detection/Image/image.py:130: UserWarning: Target shape is not a multiple below initial shape
#   warnings.warn('Target shape is not a multiple below initial shape')

# %%
dapi.image_raw.shape
dapi.show_image()
# Out:
# /Users/remydubois/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
